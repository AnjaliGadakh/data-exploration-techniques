# %%
#DATA EXPLORATION TECHNIQUES

# %%
#Once you have loaded .csv/ .xlxs File in Python You can use

# %% [markdown]
# 1. Dimensionality Check: Shape attribute returns a two item tupple no. of rows & columns for df. For series it return 1 item tupple. REquired in order to understand the volume of your data

# %% [markdown]
# df.shape

# %% [markdown]
# 2. Type of Dataset: Type() to return the type of object

# %% [markdown]
# type(df)   Type of Dataframe

# %% [markdown]
# out: pandas.core.frame.Dataframe

# %% [markdown]
#  df['chas'].dtype   2.1 Type of a column within a DF. Easy to perform an opration on your D.

# %% [markdown]
# out: dtype['int64']

# %% [markdown]
# 3. Slicing & Indexing

# %% [markdown]
# List is arguably the most useful & ubiquitous datatype in Python.
# 3.1 Slicing is used to create a new list from an existing list. The slice() constructor is used to create a slice object that represents the set of indices specified by a range Start Stop Step
# You can use the column operator with the start index on the left & End index on the right of it to output the corresponding slice

# %% [markdown]
# Slicing: list[1, 2, 3, 4, 5]

# %% [markdown]
# list[1:3]  1-Start Index 3-End Index No

# %% [markdown]
# out: [2,3]

# %% [markdown]
# List allows you to store an enumerated set of items in one place & access an item by its position index

# %% [markdown]
# Index Starts from Zero so you can give any start index from zero or more

# %% [markdown]
# 3.2 To perform Slicing on a DF  using ILOC indexer: USe the Python ILOC indexer as

# %% [markdown]
# df.iloc[a:b, x:y] a-start index of the row b-end index of the row x-SC y-EC

# %% [markdown]
# 4. Identifying Unique Elements

# %% [markdown]
# Unique() on a column- Return a numpy array with unique values of the column
# Extracting all unique values out of 'crim' column of a DF:

# %% [markdown]
# df['crim'].unique()

# %% [markdown]
# 5. Value Extraction

# %% [markdown]
# Value() on a column- Return a numpy array with all the values of the column
# Extracting values out of 'crim' column

# %% [markdown]
# df['crim'].values()

# %%
#Python provides a statistics module, which comes with very helpful 
#statistical functions like mean, median, mode, etc.

# %% [markdown]
# 6. Arithmetic Mean

# %% [markdown]
# Total Sum of D/Total no. of D.Pts
# Measure of central location of D in a set of values that resides in range
# Mean() on DF- Returns Mean DF across all the columns

# %% [markdown]
# df.mean()

# %% [markdown]
# out: mean of all the columns in DF

# %% [markdown]
# 7. Feature Median

# %% [markdown]
# Value thatr separates upper half of the data from lower half
# Media() on DF- Returns Median of DF across all the columns

# %% [markdown]
# df.median()

# %% [markdown]
# out: median of all the columns in DF

# %% [markdown]
# 8. Feature Mode

# %% [markdown]
# Locate the central tendancy of the numeric or nominal D
# Only fn in Statistics that also applies to non numeric data
# Media() on DF- Returns Mode values of DF across all the columns or rows

# %% [markdown]
# df.mode(axis=0) axis=0 represents columns

# %% [markdown]
# df.mode(axis=1) mode calculated over rows instead of columns
